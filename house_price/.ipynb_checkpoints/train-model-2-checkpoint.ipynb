# %% [markdown]
# # 房價預測模型
# ---
# 模型01 - 對照組
#
# 使用Kaggle資料集預測房屋價格

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers

# %%
data = pd.read_csv("kc_house_data.csv")
data.shape

pd.options.display.max_columns = 25
data.head()

# data.dtypes
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
data["year"] = pd.to_numeric(data["date"].str.slice(0, 4))
data["month"] = pd.to_numeric(data["date"].str.slice(4, 6))
data["day"] = pd.to_numeric(data["date"].str.slice(6, 8))

data.drop(["id"], axis=1, inplace=True)
data.drop(["date"], axis=1, inplace=True)
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month  day
# 0    98178  47.5112 -122.257           1340        5650  2014     10   13
# 1    98125  47.7210 -122.319           1690        7639  2014     12    9
# 2    98028  47.7379 -122.233           2720        8062  2015      2   25
# 3    98136  47.5208 -122.393           1360        5000  2014     12    9
# 4    98074  47.6168 -122.045           1800        7503  2015      2   18

# %%
data_num = data.shape[0]
indexs = np.random.permutation(data_num)

train_indexs = indexs[:int(data_num*0.6)]
val_indexs = indexs[int(data_num*0.6):int(data_num*0.8)]
test_indexs = indexs[int(data_num*0.8):]

train_data = data.loc[train_indexs]
val_data = data.loc[val_indexs]
test_data = data.loc[test_indexs]

train_data.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 875    1095000.0         0       0.00         3064      4764     3.5
# 18206  1855000.0         5       3.25         5570      9600     2.0
# 9946    563500.0         4       2.50         2800     12831     2.0
# 8894    204000.0         3       1.00         1200     12500     1.5
# 14800   210000.0         2       1.00          970      8874     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 875             0     2          3      7        3064              0
# 18206           0     0          5      9        3860           1710
# 9946            0     0          3      8        2800              0
# 8894            0     0          3      6        1200              0
# 14800           0     0          3      7         970              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 875        1990             0    98102  47.6362 -122.322           2360
# 18206      1952             0    98105  47.6708 -122.262           3170
# 9946       2001             0    98019  47.7392 -121.966           2810
# 8894       1936             0    98198  47.4162 -122.329           1200
# 14800      1968             0    98056  47.4943 -122.178           1340
#
#        sqft_lot15  year  month  day
# 875          4000  2014      6   12
# 18206       10400  2014     10   15
# 9946        10235  2014      6    9
# 8894         7500  2015      4   14
# 14800        8175  2014     11   24

# %%
mean = train_data.mean()
std = train_data.std()
train_data = (train_data - mean) / std

mean = val_data.mean()
std = val_data.std()
val_data = (val_data - mean) / std

# val_data.mean()
# val_data.std()

# %%
x_train = np.array(train_data.drop("price", axis=1))
y_train = np.array(train_data["price"])
x_val = np.array(val_data.drop("price", axis=1))
y_val = np.array(val_data["price"])

print(x_val.shape)
print(y_val.shape)
# Out:
# (4323, 21)
# (4323,)

# %%
model = keras.Sequential(name="model-1")

model.add(layers.Dense(64, activation="relu", input_shape=(21, )))
model.add(layers.Dense(64, activation="relu"))
model.add(layers.Dense(1))

print(model.summary())
# Out:
# Model: "model-1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                1408
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,633
# Trainable params: 5,633
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(keras.optimizers.Adam(0.001), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

# %%
model_dir = "logs/models/"
if not os.path.exists(model_dir):
    print("new dir!")
    os.makedirs(model_dir)

log_dir = os.path.join("logs", "model-1")
model_cdk = keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp = keras.callbacks.ModelCheckpoint(model_dir+"best-model-1.h5", monitor="val_mean_absolute_error", 
                                             save_best_only=True, mode="min")

# %%
history = model.fit(x_train, y_train, batch_size=64, epochs=100,
                    validation_data=(x_val, y_val), callbacks=[model_cdk, model_mckp])
# Out:
# Epoch 1/100
# 203/203 [==============================] - 4s 9ms/step - loss: 0.3365 - mean_absolute_error: 0.3503 - val_loss: 0.2432 - val_mean_absolute_error: 0.2954
# Epoch 2/100
# 203/203 [==============================] - 2s 9ms/step - loss: 0.2119 - mean_absolute_error: 0.2829 - val_loss: 0.2132 - val_mean_absolute_error: 0.2825
# Epoch 3/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1835 - mean_absolute_error: 0.2645 - val_loss: 0.1903 - val_mean_absolute_error: 0.2626
# Epoch 4/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1674 - mean_absolute_error: 0.2529 - val_loss: 0.1772 - val_mean_absolute_error: 0.2548
# Epoch 5/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1512 - mean_absolute_error: 0.2406 - val_loss: 0.1746 - val_mean_absolute_error: 0.2506
# Epoch 6/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1393 - mean_absolute_error: 0.2325 - val_loss: 0.1687 - val_mean_absolute_error: 0.2390
# Epoch 7/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1306 - mean_absolute_error: 0.2249 - val_loss: 0.1554 - val_mean_absolute_error: 0.2323
# Epoch 8/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1228 - mean_absolute_error: 0.2184 - val_loss: 0.1575 - val_mean_absolute_error: 0.2485
# Epoch 9/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1171 - mean_absolute_error: 0.2145 - val_loss: 0.1467 - val_mean_absolute_error: 0.2222
# Epoch 10/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1096 - mean_absolute_error: 0.2078 - val_loss: 0.1450 - val_mean_absolute_error: 0.2211
# Epoch 11/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1042 - mean_absolute_error: 0.2034 - val_loss: 0.1424 - val_mean_absolute_error: 0.2277
# Epoch 12/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1007 - mean_absolute_error: 0.1996 - val_loss: 0.1414 - val_mean_absolute_error: 0.2214
# Epoch 13/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0999 - mean_absolute_error: 0.2009 - val_loss: 0.1468 - val_mean_absolute_error: 0.2188
# Epoch 14/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0952 - mean_absolute_error: 0.1969 - val_loss: 0.1349 - val_mean_absolute_error: 0.2186
# Epoch 15/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0914 - mean_absolute_error: 0.1943 - val_loss: 0.1389 - val_mean_absolute_error: 0.2160
# Epoch 16/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0889 - mean_absolute_error: 0.1921 - val_loss: 0.1407 - val_mean_absolute_error: 0.2207
# Epoch 17/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0863 - mean_absolute_error: 0.1896 - val_loss: 0.1397 - val_mean_absolute_error: 0.2155
# Epoch 18/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0880 - mean_absolute_error: 0.1901 - val_loss: 0.1375 - val_mean_absolute_error: 0.2139
# Epoch 19/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0826 - mean_absolute_error: 0.1861 - val_loss: 0.1320 - val_mean_absolute_error: 0.2111
# Epoch 20/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0817 - mean_absolute_error: 0.1847 - val_loss: 0.1392 - val_mean_absolute_error: 0.2130
# Epoch 21/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0783 - mean_absolute_error: 0.1825 - val_loss: 0.1371 - val_mean_absolute_error: 0.2076
# Epoch 22/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0771 - mean_absolute_error: 0.1807 - val_loss: 0.1396 - val_mean_absolute_error: 0.2132
# Epoch 23/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0772 - mean_absolute_error: 0.1820 - val_loss: 0.1356 - val_mean_absolute_error: 0.2170
# Epoch 24/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0770 - mean_absolute_error: 0.1831 - val_loss: 0.1319 - val_mean_absolute_error: 0.2078
# Epoch 25/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0737 - mean_absolute_error: 0.1786 - val_loss: 0.1401 - val_mean_absolute_error: 0.2096
# Epoch 26/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0721 - mean_absolute_error: 0.1759 - val_loss: 0.1359 - val_mean_absolute_error: 0.2121
# Epoch 27/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0713 - mean_absolute_error: 0.1772 - val_loss: 0.1324 - val_mean_absolute_error: 0.2066
# Epoch 28/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0689 - mean_absolute_error: 0.1745 - val_loss: 0.1292 - val_mean_absolute_error: 0.2087
# Epoch 29/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0706 - mean_absolute_error: 0.1760 - val_loss: 0.1304 - val_mean_absolute_error: 0.2078
# Epoch 30/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0682 - mean_absolute_error: 0.1736 - val_loss: 0.1382 - val_mean_absolute_error: 0.2093
# Epoch 31/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0679 - mean_absolute_error: 0.1740 - val_loss: 0.1343 - val_mean_absolute_error: 0.2126
# Epoch 32/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0664 - mean_absolute_error: 0.1716 - val_loss: 0.1289 - val_mean_absolute_error: 0.2065
# Epoch 33/100
# 203/203 [==============================] - 2s 7ms/step - loss: 0.0643 - mean_absolute_error: 0.1696 - val_loss: 0.1329 - val_mean_absolute_error: 0.2064
# Epoch 34/100
# 203/203 [==============================] - 2s 7ms/step - loss: 0.0638 - mean_absolute_error: 0.1711 - val_loss: 0.1306 - val_mean_absolute_error: 0.2060
# Epoch 35/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0635 - mean_absolute_error: 0.1682 - val_loss: 0.1347 - val_mean_absolute_error: 0.2148
# Epoch 36/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0634 - mean_absolute_error: 0.1701 - val_loss: 0.1394 - val_mean_absolute_error: 0.2075
# Epoch 37/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0625 - mean_absolute_error: 0.1692 - val_loss: 0.1482 - val_mean_absolute_error: 0.2219
# Epoch 38/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0638 - mean_absolute_error: 0.1693 - val_loss: 0.1423 - val_mean_absolute_error: 0.2128
# Epoch 39/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0612 - mean_absolute_error: 0.1686 - val_loss: 0.1349 - val_mean_absolute_error: 0.2090
# Epoch 40/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0609 - mean_absolute_error: 0.1677 - val_loss: 0.1284 - val_mean_absolute_error: 0.2060
# Epoch 41/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0581 - mean_absolute_error: 0.1641 - val_loss: 0.1396 - val_mean_absolute_error: 0.2196
# Epoch 42/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0586 - mean_absolute_error: 0.1658 - val_loss: 0.1378 - val_mean_absolute_error: 0.2123
# Epoch 43/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0576 - mean_absolute_error: 0.1640 - val_loss: 0.1322 - val_mean_absolute_error: 0.2100
# Epoch 44/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0558 - mean_absolute_error: 0.1612 - val_loss: 0.1380 - val_mean_absolute_error: 0.2119
# Epoch 45/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0580 - mean_absolute_error: 0.1646 - val_loss: 0.1337 - val_mean_absolute_error: 0.2093
# Epoch 46/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0552 - mean_absolute_error: 0.1615 - val_loss: 0.1287 - val_mean_absolute_error: 0.2066
# Epoch 47/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0556 - mean_absolute_error: 0.1619 - val_loss: 0.1390 - val_mean_absolute_error: 0.2087
# Epoch 48/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0538 - mean_absolute_error: 0.1609 - val_loss: 0.1348 - val_mean_absolute_error: 0.2070
# Epoch 49/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0555 - mean_absolute_error: 0.1611 - val_loss: 0.1400 - val_mean_absolute_error: 0.2135
# Epoch 50/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0559 - mean_absolute_error: 0.1623 - val_loss: 0.1289 - val_mean_absolute_error: 0.2069
# Epoch 51/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0565 - mean_absolute_error: 0.1627 - val_loss: 0.1309 - val_mean_absolute_error: 0.2072
# Epoch 52/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0527 - mean_absolute_error: 0.1586 - val_loss: 0.1345 - val_mean_absolute_error: 0.2124
# Epoch 53/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0525 - mean_absolute_error: 0.1591 - val_loss: 0.1338 - val_mean_absolute_error: 0.2085
# Epoch 54/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0527 - mean_absolute_error: 0.1580 - val_loss: 0.1336 - val_mean_absolute_error: 0.2102
# Epoch 55/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0528 - mean_absolute_error: 0.1591 - val_loss: 0.1367 - val_mean_absolute_error: 0.2082
# Epoch 56/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0525 - mean_absolute_error: 0.1577 - val_loss: 0.1368 - val_mean_absolute_error: 0.2092
# Epoch 57/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0502 - mean_absolute_error: 0.1564 - val_loss: 0.1366 - val_mean_absolute_error: 0.2147
# Epoch 58/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0525 - mean_absolute_error: 0.1588 - val_loss: 0.1384 - val_mean_absolute_error: 0.2125
# Epoch 59/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0508 - mean_absolute_error: 0.1567 - val_loss: 0.1354 - val_mean_absolute_error: 0.2147
# Epoch 60/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0511 - mean_absolute_error: 0.1564 - val_loss: 0.1345 - val_mean_absolute_error: 0.2160
# Epoch 61/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0496 - mean_absolute_error: 0.1554 - val_loss: 0.1322 - val_mean_absolute_error: 0.2128
# Epoch 62/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0474 - mean_absolute_error: 0.1528 - val_loss: 0.1313 - val_mean_absolute_error: 0.2074
# Epoch 63/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0497 - mean_absolute_error: 0.1555 - val_loss: 0.1461 - val_mean_absolute_error: 0.2130
# Epoch 64/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0479 - mean_absolute_error: 0.1541 - val_loss: 0.1295 - val_mean_absolute_error: 0.2072
# Epoch 65/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0484 - mean_absolute_error: 0.1543 - val_loss: 0.1356 - val_mean_absolute_error: 0.2136
# Epoch 66/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0476 - mean_absolute_error: 0.1534 - val_loss: 0.1305 - val_mean_absolute_error: 0.2095
# Epoch 67/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0465 - mean_absolute_error: 0.1519 - val_loss: 0.1372 - val_mean_absolute_error: 0.2105
# Epoch 68/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0474 - mean_absolute_error: 0.1529 - val_loss: 0.1373 - val_mean_absolute_error: 0.2148
# Epoch 69/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0468 - mean_absolute_error: 0.1529 - val_loss: 0.1346 - val_mean_absolute_error: 0.2114
# Epoch 70/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0508 - mean_absolute_error: 0.1569 - val_loss: 0.1378 - val_mean_absolute_error: 0.2122
# Epoch 71/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0456 - mean_absolute_error: 0.1509 - val_loss: 0.1348 - val_mean_absolute_error: 0.2106
# Epoch 72/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0450 - mean_absolute_error: 0.1499 - val_loss: 0.1387 - val_mean_absolute_error: 0.2145
# Epoch 73/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0468 - mean_absolute_error: 0.1522 - val_loss: 0.1373 - val_mean_absolute_error: 0.2123
# Epoch 74/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0469 - mean_absolute_error: 0.1520 - val_loss: 0.1378 - val_mean_absolute_error: 0.2133
# Epoch 75/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0451 - mean_absolute_error: 0.1498 - val_loss: 0.1377 - val_mean_absolute_error: 0.2134
# Epoch 76/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0433 - mean_absolute_error: 0.1477 - val_loss: 0.1413 - val_mean_absolute_error: 0.2135
# Epoch 77/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0436 - mean_absolute_error: 0.1487 - val_loss: 0.1354 - val_mean_absolute_error: 0.2113
# Epoch 78/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0423 - mean_absolute_error: 0.1463 - val_loss: 0.1378 - val_mean_absolute_error: 0.2171
# Epoch 79/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0444 - mean_absolute_error: 0.1490 - val_loss: 0.1383 - val_mean_absolute_error: 0.2188
# Epoch 80/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0444 - mean_absolute_error: 0.1496 - val_loss: 0.1367 - val_mean_absolute_error: 0.2121
# Epoch 81/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0437 - mean_absolute_error: 0.1478 - val_loss: 0.1403 - val_mean_absolute_error: 0.2179
# Epoch 82/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0419 - mean_absolute_error: 0.1459 - val_loss: 0.1431 - val_mean_absolute_error: 0.2159
# Epoch 83/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0421 - mean_absolute_error: 0.1459 - val_loss: 0.1394 - val_mean_absolute_error: 0.2153
# Epoch 84/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0404 - mean_absolute_error: 0.1444 - val_loss: 0.1425 - val_mean_absolute_error: 0.2134
# Epoch 85/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0402 - mean_absolute_error: 0.1450 - val_loss: 0.1399 - val_mean_absolute_error: 0.2140
# Epoch 86/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0415 - mean_absolute_error: 0.1455 - val_loss: 0.1438 - val_mean_absolute_error: 0.2202
# Epoch 87/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0415 - mean_absolute_error: 0.1458 - val_loss: 0.1421 - val_mean_absolute_error: 0.2134
# Epoch 88/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0442 - mean_absolute_error: 0.1474 - val_loss: 0.1406 - val_mean_absolute_error: 0.2142
# Epoch 89/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0426 - mean_absolute_error: 0.1472 - val_loss: 0.1390 - val_mean_absolute_error: 0.2133
# Epoch 90/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0399 - mean_absolute_error: 0.1443 - val_loss: 0.1433 - val_mean_absolute_error: 0.2144
# Epoch 91/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0397 - mean_absolute_error: 0.1428 - val_loss: 0.1443 - val_mean_absolute_error: 0.2152
# Epoch 92/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0400 - mean_absolute_error: 0.1443 - val_loss: 0.1414 - val_mean_absolute_error: 0.2154
# Epoch 93/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0407 - mean_absolute_error: 0.1454 - val_loss: 0.1440 - val_mean_absolute_error: 0.2148
# Epoch 94/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0389 - mean_absolute_error: 0.1428 - val_loss: 0.1444 - val_mean_absolute_error: 0.2227
# Epoch 95/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0411 - mean_absolute_error: 0.1447 - val_loss: 0.1447 - val_mean_absolute_error: 0.2127
# Epoch 96/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0428 - mean_absolute_error: 0.1475 - val_loss: 0.1391 - val_mean_absolute_error: 0.2110
# Epoch 97/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0394 - mean_absolute_error: 0.1433 - val_loss: 0.1390 - val_mean_absolute_error: 0.2132
# Epoch 98/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0401 - mean_absolute_error: 0.1435 - val_loss: 0.1428 - val_mean_absolute_error: 0.2159
# Epoch 99/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0384 - mean_absolute_error: 0.1417 - val_loss: 0.1422 - val_mean_absolute_error: 0.2173
# Epoch 100/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0395 - mean_absolute_error: 0.1434 - val_loss: 0.1389 - val_mean_absolute_error: 0.2132

# %%
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend(loc="upper right")
plt.title('MSE')
# Out:
# Text(0.5, 1.0, 'MSE')

# %%
plt.plot(history.history["mean_absolute_error"], label="train")
plt.plot(history.history["val_mean_absolute_error"], label="val")
plt.xlabel("epochs")
plt.ylabel("metrics")
plt.legend(loc="upper right")
plt.title('MAE')
# Out:
# Text(0.5, 1.0, 'MAE')

# %%
model.load_weights("logs/models/best-model-1.h5")

y_test = np.array(test_data["price"])
mean = test_data.mean()
std = test_data.std()
test_data = (test_data - mean) / std
x_test = np.array(test_data.drop("price", axis=1))

y_pred = model.predict(x_test)

y_pred = np.reshape(y_pred * std["price"] + mean["price"], y_test.shape)
precentage_error = np.mean(np.abs(y_test - y_pred)) / np.mean(y_test) * 100

print("Model precentage error: {:.2f}%".format(precentage_error))
# Out:
# Model precentage error: 13.93%

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
# %reload_ext tensorboard

# %% [markdown]
# # 房價預測模型
# ---
# 模型02 - 減少模型大小
#
# 使用Kaggle資料集預測房屋價格

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers

# %%
data = pd.read_csv("kc_house_data.csv")
data.shape

pd.options.display.max_columns = 25
data.head()

# data.dtypes
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
data["year"] = pd.to_numeric(data["date"].str.slice(0, 4))
data["month"] = pd.to_numeric(data["date"].str.slice(4, 6))
data["day"] = pd.to_numeric(data["date"].str.slice(6, 8))

data.drop(["id"], axis=1, inplace=True)
data.drop(["date"], axis=1, inplace=True)
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month  day
# 0    98178  47.5112 -122.257           1340        5650  2014     10   13
# 1    98125  47.7210 -122.319           1690        7639  2014     12    9
# 2    98028  47.7379 -122.233           2720        8062  2015      2   25
# 3    98136  47.5208 -122.393           1360        5000  2014     12    9
# 4    98074  47.6168 -122.045           1800        7503  2015      2   18

# %%
data_num = data.shape[0]
indexs = np.random.permutation(data_num)

train_indexs = indexs[:int(data_num*0.6)]
val_indexs = indexs[int(data_num*0.6):int(data_num*0.8)]
test_indexs = indexs[int(data_num*0.8):]

train_data = data.loc[train_indexs]
val_data = data.loc[val_indexs]
test_data = data.loc[test_indexs]

train_data.head()
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2097   688000.0         4       3.00         3000      4000     1.5
# 1651   255000.0         2       1.50         1480      9660     1.0
# 16306  280000.0         3       2.50         1550      4486     2.0
# 16222  439000.0         3       2.25         2230      4551     1.5
# 12261  255000.0         3       1.50         1060      9039     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 2097            0     3          3      8        1970           1030
# 1651            0     0          3      7        1480              0
# 16306           0     0          3      7        1550              0
# 16222           0     2          5      8        1450            780
# 12261           0     0          3      7        1060              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 2097       1913          2014    98144  47.5744 -122.307           1900
# 1651       1949             0    98188  47.4577 -122.289           1990
# 16306      2000             0    98001  47.3299 -122.269           1700
# 16222      1928             0    98178  47.5078 -122.236           2060
# 12261      1973          2013    98058  47.4293 -122.151           1410
#
#        sqft_lot15  year  month  day
# 2097         4000  2014      5   27
# 1651         9660  2015      4   24
# 16306        4487  2015      5    7
# 16222        7200  2014      9    4
# 12261        9515  2014      5   21

# %%
mean = train_data.mean()
std = train_data.std()
train_data = (train_data - mean) / std

mean = val_data.mean()
std = val_data.std()
val_data = (val_data - mean) / std

# val_data.mean()
# val_data.std()

# %%
x_train = np.array(train_data.drop("price", axis=1))
y_train = np.array(train_data["price"])
x_val = np.array(val_data.drop("price", axis=1))
y_val = np.array(val_data["price"])

print(x_val.shape)
print(y_val.shape)
# Out:
# (4323, 21)
# (4323,)

# %%
model = keras.Sequential(name="model-2")

model.add(layers.Dense(32, activation="relu", input_shape=(21, )))
model.add(layers.Dense(32, activation="relu"))
model.add(layers.Dense(1))

print(model.summary())
# Out:
# Model: "model-2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                704
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,793
# Trainable params: 1,793
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(keras.optimizers.Adam(0.001), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

# %%
model_dir = "logs/models/"
if not os.path.exists(model_dir):
    print("new dir!")
    os.makedirs(model_dir)

log_dir = os.path.join("logs", "model-2")
model_cdk = keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp = keras.callbacks.ModelCheckpoint(model_dir+"best-model-2.h5", monitor="val_mean_absolute_error", 
                                             save_best_only=True, mode="min")

# %%
history = model.fit(x_train, y_train, batch_size=64, epochs=100,
                    validation_data=(x_val, y_val), callbacks=[model_cdk, model_mckp])
# Out:
# Epoch 1/100
# 203/203 [==============================] - 2s 9ms/step - loss: 0.3652 - mean_absolute_error: 0.3992 - val_loss: 0.2680 - val_mean_absolute_error: 0.3257
# Epoch 2/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.2368 - mean_absolute_error: 0.3139 - val_loss: 0.2272 - val_mean_absolute_error: 0.2891
# Epoch 3/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2055 - mean_absolute_error: 0.2874 - val_loss: 0.2041 - val_mean_absolute_error: 0.2679
# Epoch 4/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1894 - mean_absolute_error: 0.2735 - val_loss: 0.1921 - val_mean_absolute_error: 0.2567
# Epoch 5/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1745 - mean_absolute_error: 0.2618 - val_loss: 0.1868 - val_mean_absolute_error: 0.2572
# Epoch 6/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1644 - mean_absolute_error: 0.2530 - val_loss: 0.1720 - val_mean_absolute_error: 0.2461
# Epoch 7/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1547 - mean_absolute_error: 0.2443 - val_loss: 0.1634 - val_mean_absolute_error: 0.2378
# Epoch 8/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1459 - mean_absolute_error: 0.2365 - val_loss: 0.1663 - val_mean_absolute_error: 0.2393
# Epoch 9/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1436 - mean_absolute_error: 0.2370 - val_loss: 0.1567 - val_mean_absolute_error: 0.2295
# Epoch 10/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1341 - mean_absolute_error: 0.2265 - val_loss: 0.1542 - val_mean_absolute_error: 0.2316
# Epoch 11/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1307 - mean_absolute_error: 0.2245 - val_loss: 0.1457 - val_mean_absolute_error: 0.2155
# Epoch 12/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1264 - mean_absolute_error: 0.2200 - val_loss: 0.1439 - val_mean_absolute_error: 0.2161
# Epoch 13/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1232 - mean_absolute_error: 0.2174 - val_loss: 0.1343 - val_mean_absolute_error: 0.2131
# Epoch 14/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1190 - mean_absolute_error: 0.2134 - val_loss: 0.1355 - val_mean_absolute_error: 0.2134
# Epoch 15/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1169 - mean_absolute_error: 0.2133 - val_loss: 0.1391 - val_mean_absolute_error: 0.2195
# Epoch 16/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1140 - mean_absolute_error: 0.2093 - val_loss: 0.1342 - val_mean_absolute_error: 0.2106
# Epoch 17/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1142 - mean_absolute_error: 0.2082 - val_loss: 0.1295 - val_mean_absolute_error: 0.2081
# Epoch 18/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1096 - mean_absolute_error: 0.2062 - val_loss: 0.1301 - val_mean_absolute_error: 0.2081
# Epoch 19/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.1083 - mean_absolute_error: 0.2035 - val_loss: 0.1295 - val_mean_absolute_error: 0.2073
# Epoch 20/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1056 - mean_absolute_error: 0.2030 - val_loss: 0.1250 - val_mean_absolute_error: 0.2098
# Epoch 21/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1052 - mean_absolute_error: 0.2028 - val_loss: 0.1261 - val_mean_absolute_error: 0.2029
# Epoch 22/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1020 - mean_absolute_error: 0.1990 - val_loss: 0.1221 - val_mean_absolute_error: 0.2050
# Epoch 23/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1006 - mean_absolute_error: 0.1986 - val_loss: 0.1291 - val_mean_absolute_error: 0.2162
# Epoch 24/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.1011 - mean_absolute_error: 0.1983 - val_loss: 0.1213 - val_mean_absolute_error: 0.2037
# Epoch 25/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0990 - mean_absolute_error: 0.1971 - val_loss: 0.1240 - val_mean_absolute_error: 0.2109
# Epoch 26/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0979 - mean_absolute_error: 0.1960 - val_loss: 0.1251 - val_mean_absolute_error: 0.2125
# Epoch 27/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0985 - mean_absolute_error: 0.1977 - val_loss: 0.1178 - val_mean_absolute_error: 0.1977
# Epoch 28/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0954 - mean_absolute_error: 0.1950 - val_loss: 0.1144 - val_mean_absolute_error: 0.2018
# Epoch 29/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0954 - mean_absolute_error: 0.1944 - val_loss: 0.1136 - val_mean_absolute_error: 0.1989
# Epoch 30/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0948 - mean_absolute_error: 0.1948 - val_loss: 0.1147 - val_mean_absolute_error: 0.1989
# Epoch 31/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0929 - mean_absolute_error: 0.1928 - val_loss: 0.1173 - val_mean_absolute_error: 0.2023
# Epoch 32/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0910 - mean_absolute_error: 0.1907 - val_loss: 0.1154 - val_mean_absolute_error: 0.2008
# Epoch 33/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0906 - mean_absolute_error: 0.1909 - val_loss: 0.1131 - val_mean_absolute_error: 0.1983
# Epoch 34/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0910 - mean_absolute_error: 0.1922 - val_loss: 0.1144 - val_mean_absolute_error: 0.2030
# Epoch 35/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0904 - mean_absolute_error: 0.1914 - val_loss: 0.1143 - val_mean_absolute_error: 0.2020
# Epoch 36/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0890 - mean_absolute_error: 0.1900 - val_loss: 0.1129 - val_mean_absolute_error: 0.1988
# Epoch 37/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0895 - mean_absolute_error: 0.1899 - val_loss: 0.1166 - val_mean_absolute_error: 0.1999
# Epoch 38/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0885 - mean_absolute_error: 0.1895 - val_loss: 0.1166 - val_mean_absolute_error: 0.2042
# Epoch 39/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0871 - mean_absolute_error: 0.1893 - val_loss: 0.1177 - val_mean_absolute_error: 0.2072
# Epoch 40/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0877 - mean_absolute_error: 0.1899 - val_loss: 0.1200 - val_mean_absolute_error: 0.2097
# Epoch 41/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0851 - mean_absolute_error: 0.1870 - val_loss: 0.1127 - val_mean_absolute_error: 0.2010
# Epoch 42/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0867 - mean_absolute_error: 0.1876 - val_loss: 0.1150 - val_mean_absolute_error: 0.1958
# Epoch 43/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0864 - mean_absolute_error: 0.1898 - val_loss: 0.1125 - val_mean_absolute_error: 0.2092
# Epoch 44/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0849 - mean_absolute_error: 0.1869 - val_loss: 0.1231 - val_mean_absolute_error: 0.2093
# Epoch 45/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0834 - mean_absolute_error: 0.1854 - val_loss: 0.1108 - val_mean_absolute_error: 0.2049
# Epoch 46/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0826 - mean_absolute_error: 0.1851 - val_loss: 0.1152 - val_mean_absolute_error: 0.2022
# Epoch 47/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0845 - mean_absolute_error: 0.1877 - val_loss: 0.1121 - val_mean_absolute_error: 0.2074
# Epoch 48/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0845 - mean_absolute_error: 0.1874 - val_loss: 0.1138 - val_mean_absolute_error: 0.2081
# Epoch 49/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0836 - mean_absolute_error: 0.1859 - val_loss: 0.1087 - val_mean_absolute_error: 0.1947
# Epoch 50/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0823 - mean_absolute_error: 0.1859 - val_loss: 0.1131 - val_mean_absolute_error: 0.2038
# Epoch 51/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0823 - mean_absolute_error: 0.1855 - val_loss: 0.1121 - val_mean_absolute_error: 0.1982
# Epoch 52/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0813 - mean_absolute_error: 0.1839 - val_loss: 0.1106 - val_mean_absolute_error: 0.1976
# Epoch 53/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0816 - mean_absolute_error: 0.1856 - val_loss: 0.1138 - val_mean_absolute_error: 0.2021
# Epoch 54/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0801 - mean_absolute_error: 0.1831 - val_loss: 0.1111 - val_mean_absolute_error: 0.2003
# Epoch 55/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0800 - mean_absolute_error: 0.1830 - val_loss: 0.1091 - val_mean_absolute_error: 0.1966
# Epoch 56/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0800 - mean_absolute_error: 0.1835 - val_loss: 0.1100 - val_mean_absolute_error: 0.1979
# Epoch 57/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0807 - mean_absolute_error: 0.1850 - val_loss: 0.1148 - val_mean_absolute_error: 0.2012
# Epoch 58/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0788 - mean_absolute_error: 0.1824 - val_loss: 0.1090 - val_mean_absolute_error: 0.1991
# Epoch 59/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0774 - mean_absolute_error: 0.1813 - val_loss: 0.1114 - val_mean_absolute_error: 0.1981
# Epoch 60/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0783 - mean_absolute_error: 0.1816 - val_loss: 0.1108 - val_mean_absolute_error: 0.2012
# Epoch 61/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0768 - mean_absolute_error: 0.1807 - val_loss: 0.1082 - val_mean_absolute_error: 0.1969
# Epoch 62/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0777 - mean_absolute_error: 0.1816 - val_loss: 0.1098 - val_mean_absolute_error: 0.1996
# Epoch 63/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0760 - mean_absolute_error: 0.1799 - val_loss: 0.1123 - val_mean_absolute_error: 0.2024
# Epoch 64/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0759 - mean_absolute_error: 0.1812 - val_loss: 0.1109 - val_mean_absolute_error: 0.1972
# Epoch 65/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0759 - mean_absolute_error: 0.1806 - val_loss: 0.1119 - val_mean_absolute_error: 0.2008
# Epoch 66/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0767 - mean_absolute_error: 0.1806 - val_loss: 0.1112 - val_mean_absolute_error: 0.2025
# Epoch 67/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0755 - mean_absolute_error: 0.1797 - val_loss: 0.1098 - val_mean_absolute_error: 0.1990
# Epoch 68/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0747 - mean_absolute_error: 0.1783 - val_loss: 0.1200 - val_mean_absolute_error: 0.2146
# Epoch 69/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0744 - mean_absolute_error: 0.1799 - val_loss: 0.1118 - val_mean_absolute_error: 0.2020
# Epoch 70/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0744 - mean_absolute_error: 0.1795 - val_loss: 0.1191 - val_mean_absolute_error: 0.2119
# Epoch 71/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0732 - mean_absolute_error: 0.1786 - val_loss: 0.1169 - val_mean_absolute_error: 0.2059
# Epoch 72/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0758 - mean_absolute_error: 0.1801 - val_loss: 0.1115 - val_mean_absolute_error: 0.2051
# Epoch 73/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0739 - mean_absolute_error: 0.1787 - val_loss: 0.1132 - val_mean_absolute_error: 0.2044
# Epoch 74/100
# 203/203 [==============================] - 2s 8ms/step - loss: 0.0730 - mean_absolute_error: 0.1776 - val_loss: 0.1155 - val_mean_absolute_error: 0.2040
# Epoch 75/100
# 203/203 [==============================] - 2s 8ms/step - loss: 0.0739 - mean_absolute_error: 0.1802 - val_loss: 0.1098 - val_mean_absolute_error: 0.2009
# Epoch 76/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0726 - mean_absolute_error: 0.1781 - val_loss: 0.1143 - val_mean_absolute_error: 0.1985
# Epoch 77/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0729 - mean_absolute_error: 0.1784 - val_loss: 0.1205 - val_mean_absolute_error: 0.2102
# Epoch 78/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0756 - mean_absolute_error: 0.1806 - val_loss: 0.1101 - val_mean_absolute_error: 0.1987
# Epoch 79/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0717 - mean_absolute_error: 0.1768 - val_loss: 0.1163 - val_mean_absolute_error: 0.2095
# Epoch 80/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0724 - mean_absolute_error: 0.1775 - val_loss: 0.1136 - val_mean_absolute_error: 0.2025
# Epoch 81/100
# 203/203 [==============================] - 1s 7ms/step - loss: 0.0719 - mean_absolute_error: 0.1765 - val_loss: 0.1107 - val_mean_absolute_error: 0.2025
# Epoch 82/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0724 - mean_absolute_error: 0.1785 - val_loss: 0.1134 - val_mean_absolute_error: 0.2020
# Epoch 83/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0706 - mean_absolute_error: 0.1760 - val_loss: 0.1108 - val_mean_absolute_error: 0.1984
# Epoch 84/100
# 203/203 [==============================] - 2s 10ms/step - loss: 0.0707 - mean_absolute_error: 0.1758 - val_loss: 0.1167 - val_mean_absolute_error: 0.2012
# Epoch 85/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0707 - mean_absolute_error: 0.1757 - val_loss: 0.1140 - val_mean_absolute_error: 0.2038
# Epoch 86/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0708 - mean_absolute_error: 0.1760 - val_loss: 0.1140 - val_mean_absolute_error: 0.1996
# Epoch 87/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0714 - mean_absolute_error: 0.1762 - val_loss: 0.1117 - val_mean_absolute_error: 0.2001
# Epoch 88/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0697 - mean_absolute_error: 0.1756 - val_loss: 0.1219 - val_mean_absolute_error: 0.2065
# Epoch 89/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0722 - mean_absolute_error: 0.1775 - val_loss: 0.1125 - val_mean_absolute_error: 0.2007
# Epoch 90/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0690 - mean_absolute_error: 0.1748 - val_loss: 0.1141 - val_mean_absolute_error: 0.2080
# Epoch 91/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0698 - mean_absolute_error: 0.1752 - val_loss: 0.1136 - val_mean_absolute_error: 0.2018
# Epoch 92/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0706 - mean_absolute_error: 0.1757 - val_loss: 0.1226 - val_mean_absolute_error: 0.2123
# Epoch 93/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0684 - mean_absolute_error: 0.1740 - val_loss: 0.1189 - val_mean_absolute_error: 0.2001
# Epoch 94/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0700 - mean_absolute_error: 0.1763 - val_loss: 0.1156 - val_mean_absolute_error: 0.2021
# Epoch 95/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0696 - mean_absolute_error: 0.1752 - val_loss: 0.1201 - val_mean_absolute_error: 0.2080
# Epoch 96/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0690 - mean_absolute_error: 0.1753 - val_loss: 0.1204 - val_mean_absolute_error: 0.2123
# Epoch 97/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0685 - mean_absolute_error: 0.1742 - val_loss: 0.1099 - val_mean_absolute_error: 0.1977
# Epoch 98/100
# 203/203 [==============================] - 1s 6ms/step - loss: 0.0702 - mean_absolute_error: 0.1754 - val_loss: 0.1114 - val_mean_absolute_error: 0.1973
# Epoch 99/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0683 - mean_absolute_error: 0.1750 - val_loss: 0.1127 - val_mean_absolute_error: 0.1979
# Epoch 100/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0675 - mean_absolute_error: 0.1738 - val_loss: 0.1141 - val_mean_absolute_error: 0.2010

# %%
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend(loc="upper right")
plt.title('MSE')
# Out:
# Text(0.5, 1.0, 'MSE')

# %%
plt.plot(history.history["mean_absolute_error"], label="train")
plt.plot(history.history["val_mean_absolute_error"], label="val")
plt.xlabel("epochs")
plt.ylabel("metrics")
plt.legend(loc="upper right")
plt.title('MAE')
# Out:
# Text(0.5, 1.0, 'MAE')

# %%
model.load_weights("logs/models/best-model-2.h5")

y_test = np.array(test_data["price"])
mean = test_data.mean()
std = test_data.std()
test_data = (test_data - mean) / std
x_test = np.array(test_data.drop("price", axis=1))

y_pred = model.predict(x_test)

y_pred = np.reshape(y_pred * std["price"] + mean["price"], y_test.shape)
precentage_error = np.mean(np.abs(y_test - y_pred)) / np.mean(y_test) * 100

print("Model precentage error: {:.2f}%".format(precentage_error))
# Out:
# Model precentage error: 13.87%

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
# %reload_ext tensorboard
